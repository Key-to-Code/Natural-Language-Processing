# %%
import nltk
nltk.download('punkt_tab')
import string
from collections import Counter

def getTokens():
    with open('assignment1.txt' ,'r') as file:
        text=file.read()
        lower=text.lower()
        no_punctuation = lower.translate(str.maketrans('', '', string.punctuation))
        tokens=nltk.word_tokenize(no_punctuation)
        return tokens

tokens = getTokens()
count = Counter(tokens)
print(count.most_common(10))
# Out:
# [nltk_data] Downloading package punkt_tab to /Users/anuja/nltk_data...
# [('parotta', 7), ('i', 7), ('and', 6), ('a', 5), ('is', 4), ('its', 4), ('it', 3), ('the', 3), ('my', 2), ('food', 2)]
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

tokens = getTokens()
filtered = [w for w in tokens if not w in stopwords.words('english')]
count = Counter(filtered)
print(count.most_common(100))
# Out:
# [nltk_data] Downloading package stopwords to /Users/anuja/nltk_data...
# [('parotta', 7), ('food', 2), ('soft', 2), ('delicious', 2), ('taste', 2), ('enjoy', 2), ('different', 2), ('varieties', 2), ('favorite', 1), ('flaky', 1), ('layers', 1), ('eating', 1), ('hot', 1), ('spicy', 1), ('chicken', 1), ('curry', 1), ('salna', 1), ('enhances', 1), ('flavor', 1), ('crispy', 1), ('outer', 1), ('layer', 1), ('inner', 1), ('texture', 1), ('make', 1), ('every', 1), ('bite', 1), ('satisfying', 1), ('whether', 1), ('local', 1), ('restaurant', 1), ('roadside', 1), ('stall', 1), ('family', 1), ('dinner', 1), ('always', 1), ('first', 1), ('choice', 1), ('also', 1), ('like', 1), ('trying', 1), ('kerala', 1), ('coin', 1), ('chilli', 1), ('unique', 1), ('preparation', 1), ('style', 1), ('whenever', 1), ('get', 1), ('chance', 1), ('never', 1), ('miss', 1), ('opportunity', 1), ('one', 1), ('enjoyable', 1), ('comfort', 1), ('foods', 1), ('since', 1), ('strong', 1), ('preference', 1), ('eagerly', 1), ('confidently', 1), ('say', 1), ('foodie', 1), ('loves', 1), ('exploring', 1), ('enjoying', 1)]
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from nltk.stem.porter import *

def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

stemmer = PorterStemmer()
stemmed = stem_tokens(filtered, stemmer)
count = Counter(stemmed)
print(count.most_common(100))
# Out:
# [('parotta', 7), ('enjoy', 4), ('food', 3), ('soft', 2), ('layer', 2), ('delici', 2), ('tast', 2), ('differ', 2), ('varieti', 2), ('favorit', 1), ('flaki', 1), ('eat', 1), ('hot', 1), ('spici', 1), ('chicken', 1), ('curri', 1), ('salna', 1), ('enhanc', 1), ('flavor', 1), ('crispi', 1), ('outer', 1), ('inner', 1), ('textur', 1), ('make', 1), ('everi', 1), ('bite', 1), ('satisfi', 1), ('whether', 1), ('local', 1), ('restaur', 1), ('roadsid', 1), ('stall', 1), ('famili', 1), ('dinner', 1), ('alway', 1), ('first', 1), ('choic', 1), ('also', 1), ('like', 1), ('tri', 1), ('kerala', 1), ('coin', 1), ('chilli', 1), ('uniqu', 1), ('prepar', 1), ('style', 1), ('whenev', 1), ('get', 1), ('chanc', 1), ('never', 1), ('miss', 1), ('opportun', 1), ('one', 1), ('comfort', 1), ('sinc', 1), ('strong', 1), ('prefer', 1), ('eagerli', 1), ('confid', 1), ('say', 1), ('foodi', 1), ('love', 1), ('explor', 1)]
